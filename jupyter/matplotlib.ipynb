# %% [markdown]
# ### 7.5pyplot

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
import datetime
from matplotlib import dates as mdates
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# 7.5.1生成简单的图标

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# 7.5.2设置图形的属性

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My title plot')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %% [markdown]
# 7.5.3 matplotlib和numpy

# %%
t = np.arange(0,2.5,0.1)
y1 = list(map(math.sin,math.pi*t))
y2 = list(map(math.sin,math.pi*t+math.pi/4))
y3 = list(map(math.sin,math.pi*t-math.pi/4))
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')

# %%
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r')

# %% [markdown]
# ### 7.6使用kwargs

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.0)

# %%
#subplot(***),按水平方向划分为基本为，按垂直方向划分几部分，控制子图
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(211)
plt.plot(t,y1,'b-.')
plt.subplot(212)
plt.plot(t,y2,'r--')

# %%
t = np.arange(0,1,0.05)
y1 = np.sin(2*np.pi*t)
y2 = np.cos(2*np.pi*t)
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r-')

# %% [markdown]
# ### 7.7为图标添加更多的元素

# %% [markdown]
# 7.7.1添加文本

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title("My first plot",fontname='Times New Roman',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.plot([1,2,3,4],[1,4,9,16],'ro')
# Out:
# /home/jakey/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#text允许在任意位置添加文本 text(x,y,s,fontdict=None,kwargs)
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Forth')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
#r'$  $'添加公式，表达式，希腊文字，bbox添加边框
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Forth')
plt.text(1.1,12,r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.9})#alpha 透明度
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %% [markdown]
# 7.7.2 添加网格

# %%
#grid(True),添加网格
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Forth')
plt.text(1.1,12,r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.9})#alpha 颜色的深浅
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %% [markdown]
# 7.7.3添加图例

# %%
#lengend()函数将图例和字符串类型的图形说明添加到图表中
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Forth')
plt.text(1.1,12,r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.9})#alpha 颜色的深浅
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.legend(['First series'])

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20)
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Forth')
plt.text(1.1,12,r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.9})#alpha 颜色的深浅
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'])
plt.savefig('pic.png')#保存图片

# %% [markdown]
# ### 处理日期值

# %%
events = [datetime.date(2018,1,23),datetime.date(2018,1,28),datetime.date(2018,2,3),
         datetime.date(2018,2,21),datetime.date(2018,3,15),datetime.date(2018,3,24),
         datetime.date(2018,4,8),datetime.date(2018,4,24)]
readings = [12,22,25,20,18,15,17,14]
plt.plot(events,readings)
#x轴的下标异常模糊

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%Y-%m')
events = [datetime.date(2018,1,23),datetime.date(2018,1,28),datetime.date(2018,2,3),
         datetime.date(2018,2,21),datetime.date(2018,3,15),datetime.date(2018,3,24),
         datetime.date(2018,4,8),datetime.date(2018,4,24)]
readings = [12,22,25,20,18,15,17,14]
fig,ax = plt.subplots()
plt.plot(events,readings)
#ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %% [markdown]
# ### 7.10图标类型

# %% [markdown]
# 7.11线形图

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
plt.plot(x,y)

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(4*x)/x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.grid(True)
plt.legend(['sin(3*x)','sin(2*x)','sin(4*x)'])

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(2*x)/x
y2 = np.sin(3*x)/x
y3 = np.sin(4*x)/x
plt.plot(x,y1,'k--',linewidth=3)
plt.plot(x,y2,'y-.')
plt.plot(x,y3,'g--')
plt.grid(True)
plt.legend(['sin(2*x)','sin(3*x)','sin(4*x)'])

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(2*x)/x
y2 = np.sin(3*x)/x
y3 = np.sin(4*x)/x
plt.plot(x,y1,'k--',linewidth=3)
plt.plot(x,y2,'y-.')
plt.plot(x,y3,'g--')
plt.grid(True)
plt.legend(['sin(2*x)','sin(3*x)','sin(4*x)'])
plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],
          [r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])
plt.yticks([-1,0,1,2,3],
          [r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fc2a0dbe160>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
#pandas数据结构绘制现象图
data = {'series1':[1,3,4,3,5],
       'series2':[2,4,5,2,3],
       'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
x = np.arange(5)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data)

# %% [markdown]
# 7.1.2 直方图

# %%
pop = np.random.randint(0,100,100)
n,bins,patchwe = plt.hist(pop,bins=20)#统计面元个数

# %% [markdown]
# 7.13条状图

# %%
index=[0,1,2,3,4]
values=[5,7,3,4,6]
plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
index=np.arange(5)
values1=[5,7,3,4,6]
plt.bar(index,values)
plt.xticks(index,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fc298b48208>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#yerr误差,erroe_kw误差相关参数
index = np.arange(5)
values1 = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.title('A Bar Chart')
plt.bar(index,values1,yerr=std1,error_kw={'ecolor':'0.1',
       'capsize':6},alpha=0.7,label='First')
#ecolor误差线的颜色，capsize误差线上下的长度，alpha透明度
plt.xticks(index,['A','B','C','D','E'])
plt.legend(['first'],loc=2)

# %% [markdown]
# 7.13.1 水平条状图

# %%
#barh水平条状图,yerr误差参数，error_kw误差参数
index = np.arange(5)
values1 = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.title('A Bar Chart')
plt.barh(index,values1,xerr=std1,error_kw={'ecolor':'0.1',
       'capsize':6},alpha=0.7,label='First')
#ecolor误差线的颜色，capsize误差线上下的长度，alpha透明度
plt.xticks(index,['A','B','C','D','E'])
plt.legend(['first'])

# %% [markdown]
# 7.13.2 多序列条状图

# %%
index = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw = 0.3
plt.axis([-0.5,5,0,8])
plt.title('A Multiseries Bar Chart',fontsize=20)
plt.bar(index,values1,bw,color='b')
plt.bar(index+bw,values2,bw,color='g')
plt.bar(index+bw*2,values3,bw,color='r')
plt.xticks(index+bw,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fc2985295f8>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# 7.13.1 为pandas DataFrame生成多序列条状图

# %%
data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,1],
    'serise3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df.plot(kind='bar')

# %% [markdown]
# 7.13.4 多序列堆积条状图

# %%
#表达总和由几个条状图相加获得
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([-0.5,4,0,15])
plt.bar(index,series1,color='r')
plt.bar(index,series2,color='b',bottom=series1)
plt.bar(index,series3,color='g',bottom=(series1+series2))
plt.xticks(index,['Jan15','Feb15','Mar15','Apr15'])
plt.legend(['1','2'])

# %% [markdown]
# 7.13.5 为pandas DataFrame绘制堆积条状图

# %%
data = {'series1':[1,3,4,3,5],
       'series2':[2,4,5,2,4],
       'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar',stacked=True)

# %% [markdown]
# 7.13.6其他条状图

# %%
x0 = np.arange(8)
y1 = np.array([1,3,4,6,4,3,2,1])
y2 = np.array([1,2,5,4,3,3,2,1])
plt.ylim(-7,7)
plt.bar(x0,y1,0.9,facecolor='r',edgecolor='w')
plt.bar(x0,-y2,0.9,facecolor='b',edgecolor='w')
plt.xticks(())
plt.grid(True)
for x,y in zip(x0,y1):
    plt.text(x,y,'%d' %y,ha='center',va='bottom')
for x,y in zip(x0,y2):
    plt.text(x,-y-0.7,'%d' %(-y),ha='center',va='bottom')

# %% [markdown]
# ### 7.14 饼图

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
# Out:
# (-1.11637372803214,
#  1.1007797090739162,
#  -1.1163737124158366,
#  1.1007797083302826)

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
explode = [0.3,0,0,0]
plt.title('A Pie Chart')
plt.pie(values,labels=labels,colors=colors,explode=explode,startangle=180)
plt.axis('equal')
# Out:
# (-1.4003625034945653,
#  1.130639575385504,
#  -1.1007797083302826,
#  1.1163737124158366)

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
explode = [0.3,0,0,0]
plt.title('A Pie Chart')
plt.pie(values,labels=labels,colors=colors,explode=explode,
        shadow = True,autopct='%1.1f%%',startangle=180)
plt.axis('equal')
# Out:
# (-1.4003625034945653,
#  1.130639575385504,
#  -1.1007797083302826,
#  1.1163737124158366)

# %% [markdown]
# 为DataFrame绘制饼图

# %%
data = {'series1':[1,3,4,3,5],
       'series2':[2,4,5,2,4],
       'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df['series1'].plot(kind='pie',figsize=(6,6))
df
# Out:
#    series1  series2  series3
# 0        1        2        3
# 1        3        4        2
# 2        4        5        3
# 3        3        2        1
# 4        5        4        3

# %% [markdown]
# ### 高级图表

# %%
N =8
theta = np.arange(0,2*np.pi,2*np.pi/N)
radii = np.array([4,7,5,3,1,5,6,7])
plt.axes([0.025,0.025,0.95,0.95],polar=True)
colors = np.array(['#4bb2c5','#c5b47f','#EAA228','#579575','#839557','#958c12',
                  '#953579','#4b5de4'])
bars = plt.bar(theta,radii,width=(2*np.pi/N),bottom=0.0,color=colors)

# %%
#在画布上的布局参数
plt.axes([0,0,1,1],polar=True)
#bottom叠加
bars = plt.bar(theta,radii,width=(2*np.pi/N),bottom=0.0,color=colors)

# %% [markdown]
# ### 7.16 mplot3d

# %%
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=1)

# %%
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=1,cmap=plt.cm.winter)
ax.view_init(elev=30,azim=125)

# %% [markdown]
# 7.16.2 3D散点图

# %%
xs1 = np.random.randint(30,40,100)
ys1 = np.random.randint(20,30,100)
zs1 = np.random.randint(10,20,100)
xs2 = np.random.randint(50,60,100)
ys2 = np.random.randint(30,40,100)
zs2 = np.random.randint(50,70,100)
xs3 = np.random.randint(10,30,100)
ys3 = np.random.randint(40,50,100)
zs3 = np.random.randint(40,50,100)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(xs1,ys1,zs1)
ax.scatter(xs2,ys2,zs2,c='r',marker='^')
ax.scatter(xs3,ys3,zs3,c='g',marker='*')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5,0,'Z Label')

# %% [markdown]
# ### 7.17 多面板图形

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
inner_ax = fig.add_axes([0.6,0.6,0.25,0.25])
x1 = np.arange(10)
y1 = np.array([1,2,7,1,5,2,4,2,3,1])
x2 = np.arange(10)
y2 = np.array([1,3,4,5,4,5,2,6,4,3])
ax.plot(x1,y1)
inner_ax.plot(x2,y2)

# %% [markdown]
# 7.17.2 子图网格

# %%
#将画布分成3*3
gs = plt.GridSpec(3,3)
#改变画布大小
fig = plt.figure(figsize=(10,10))
fig.add_subplot(gs[1,:2])
fig.add_subplot(gs[0,:2])
fig.add_subplot(gs[2,0])
fig.add_subplot(gs[:2,2])
fig.add_subplot(gs[2,1:])

# %%
#将画布分成3*3
gs = plt.GridSpec(3,3)
#改变画布大小
fig = plt.figure(figsize=(10,10))
x1 = np.array([1,3,2,5])
y1 = np.array([4,3,7,2])
x2 = np.arange(5)
y2 = np.array([3,2,4,6,3])
s1 = fig.add_subplot(gs[1,:2])
s1.plot(x1,y1,'r')
s2 = fig.add_subplot(gs[0,:2])
s2.bar(x2,y2)
s3 = fig.add_subplot(gs[2,0])
s3.barh(x2,y2,color='g')
s4 = fig.add_subplot(gs[:2,2])
s4.plot(x2,y2,'k')
s5 = fig.add_subplot(gs[2,1:])
s5.plot(x1,y1,'b^',x2,y2,'yo')

# %%
x = np.arange(8)
y = np.random.randint(0,10,8)
y2 = y + np.random.randint(0,3,8)
y3 = y2 + np.random.randint(0,3,8)
y4 = y3 + np.random.randint(0,3,8)
y5 = y4 + np.random.randint(0,3,8)
clr = ['#4bb2c5','#c5b47f','#EAA228','#579575','#839557','#958c12','#953579','#4b5de4']
fig = plt.figure()
ax = Axes3D(fig)
ax.bar(x,y,0,zdir='y',color=clr)
ax.bar(x,y2,10,zdir='y',color=clr)
ax.bar(x,y3,20,zdir='y',color=clr)
ax.bar(x,y4,30,zdir='y',color=clr)
ax.bar(x,y5,40,zdir='y',color=clr)
# Out:
# <BarContainer object of 8 artists>

# %%
fig = plt.figure()  
ax = fig.add_subplot(111, projection='3d')  
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):  
    xs = np.arange(20)  
    ys = np.random.rand(20)  
  
    # You can provide either a single color or an array. To demonstrate this,  
    # the first bar of each set will be colored cyan.  
    cs = [c] * len(xs)  
    cs[0] = 'c'  
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)
